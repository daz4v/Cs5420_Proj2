# %% [markdown]
# ## 1) Find and load the dataset from the files
#  Make sure you imported the whole zip File and dont change the names of the files or it will fail
#  Outputs the dataset info in this cell like # of docs per, # classes per, Total # of docs

# %% [markdown]
# ## 2) MLP
#  This is the actual model. it works by

# %% [markdown]
# ## 3) Training, Splitting the data
